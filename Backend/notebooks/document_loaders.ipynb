# %%
from langchain_community.document_loaders import PyPDFLoader, TextLoader, Docx2txtLoader
import os
from dotenv import load_dotenv

load_dotenv()

print("success")
# Out:
# success

# %%
pdf_path = "test.pdf"
loader = PyPDFLoader(pdf_path)

documents = loader.load()

print(f"📄 Number of pages loaded: {len(documents)}")
print(f"\n📝 First page content preview:")
print(documents[0].page_content[:500])  # First 500 characters
print(f"\n🏷️  Metadata: {documents[0].metadata}")
# Out:
# 📄 Number of pages loaded: 1
#
# 📝 First page content preview:
# De Dr Abdallah ROUBI
# École NaƟonale Supérieure d’InformaƟque (ESI)
# Oued Smar – Alger
# a_roubi@esi.dz
# Le : 25 novembre 2025
#
# Objet : LeƩre de recommandaƟon – BakhƟ Nabil Abdelkaﬁ
#    Madame, Monsieur,
#    En ma qualité de maître de conférences à l’École NaƟonale Supérieure d’InformaƟque d’ Alger, j’ai le plaisir
# de recommander la candidature de l’étudiant BakhƟ Nabil Abdelkaﬁ, que j’ai eu comme étudiant durant
# l’année universitaire 2024/2025.
#    BakhƟ Nabil Abdelkaﬁ a suivi les cours et t
#
# 🏷️  Metadata: {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-11-25T20:06:28+01:00', 'author': '', 'moddate': '2025-11-25T20:06:28+01:00', 'title': 'Microsoft Word - Document (3).docx', 'source': 'test.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}

# %%
def load_document(file_path):
   _,extention = os.path.splitext(file_path)
   extention = extention.lower()
   if extention == ".pdf":
    loader = PyPDFLoader(file_path)
   elif extention == ".text":
    loader = TextLoader(file_path)
   elif extention in ["docx","doc"]:
    loader = Docx2txtLoader(file_path)
   else:
       raise ValueError(f"Unsupported file type: {extension}")

   documents = loader.load()
   return documents

# %%
# Out:
# ✅ Loaded 1 pages using smart loader!
